# %% [markdown]
# <a href="https://colab.research.google.com/github/lima-breno/data_vizualization/blob/main/DV_05_1_DESAFIO_Estiliza%C3%A7%C3%A3o_de_tabelas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01
# Vamos praticar o uso da visualização de tabelas através do Pandas. Para a prática, vamos utilizar outro conjunto de dados que está disponível para download: loja_livro_filmes.csv.
# Nele, temos um relatório de custos de venda de livros e filmes de uma loja. Durante os desafios, a missão será trabalhar com os dados para fazer tabelas que podem se adequar a necessidade de diversas análises que podem ser feitas da loja. Para um melhor entendimento dos dados, abaixo está o que representa cada dado nas colunas.
#
# - pais: país de destino do produto.
# - id_cliente: código de identificação do cliente solicitante.
# - data_pedido: data de solicitação do produto por parte do cliente.
# - data_chegada: data de chegada do produto ao endereço de entrega informado pelo cliente.
# - tipo_compra: categoria que se enquadra a compra, podendo ser Normal ou Devolução.
# - numero_pedido: código de identificação da compra realizada.
# - tamanho_pacote: tamanho do pacote para envio do pedido.
# - unidades: quantidade de unidades compradas no pedido.
# - custo_empacotamento: valor do custo da loja para empacotar o produto.
# - custo_envio: valor do custo da loja para enviar o produto.
# - tipo_desconto: categoria do tipo de desconto aplicado.
# - categoria: categoria de tipo de produto.
# - tipo_consumo: nível de consumo do produto por tempo de uso.
# - tipo_cliente: categoria de tipo de cliente.
# - custo_produto: valor total do custo que o pedido resulta para a loja.

# %% [markdown]
# ##Desafio 01
# Para esse desafio construiremos uma tabela contendo um ranking dos 9 países que são vendidos os produtos, conforme a quantidade total de unidades vendidas.

# %%
# !pip install pandas==2.0.0
# Out:
# Collecting pandas==2.0.0
#   Downloading pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.0) (1.16.0)
# Downloading pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 9.9 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.0.0 which is incompatible.
# Successfully installed pandas-2.0.0

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Curso 02 - Avançado em Python/1.4 Data Visualization: Estilização de tabelas com Python/Dados utilizados/loja_livro_filmes.csv')
df.head()
# Out:
#         pais  id_cliente data_pedido data_chegada tipo_compra  numero_pedido
# 0  Argentina   111962928  2002-02-15   2002-03-10      Normal       98091426  \
# 1  Argentina   145148150  2004-11-05   2004-11-26      Normal       98087803
# 2  Argentina   194622983  2014-09-14   2014-09-28      Normal       98072296
# 3  Argentina   220834258  2011-07-20   2011-07-30   Devolução       98077986
# 4  Argentina   220834258  2013-09-15   2017-02-15      Normal       98074234
#
#    tamanho_pacote  unidades  custo_empacotamento  custo_envio tipo_desconto
# 0  Pacote pequeno         1                  3.0         5.99  Sem desconto  \
# 1  Pacote pequeno         3                  1.0         6.99  Sem desconto
# 2  Pacote pequeno         1                  3.0         6.99  Sem desconto
# 3  Pacote pequeno         2                  1.0         3.86  Cyber Monday
# 4  Pacote pequeno         1                  2.0         4.88  Black Friday
#
#   categoria  tipo_consumo tipo_cliente  custo_produto
# 0   BlueRay  Alto Consumo          B2C           8.99
# 1   BlueRay  Alto Consumo          B2C           7.99
# 2   BlueRay  Alto Consumo          B2C           9.99
# 3   BlueRay  Alto Consumo          B2B           4.86
# 4   BlueRay  Alto Consumo          B2B           6.88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24890 entries, 0 to 24889
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pais                 24890 non-null  object
#  1   id_cliente           24890 non-null  int64
#  2   data_pedido          24890 non-null  object
#  3   data_chegada         24890 non-null  object
#  4   tipo_compra          24890 non-null  object
#  5   numero_pedido        24890 non-null  int64
#  6   tamanho_pacote       24890 non-null  object
#  7   unidades             24890 non-null  int64
#  8   custo_empacotamento  24890 non-null  float64
#  9   custo_envio          24890 non-null  float64
#  10  tipo_desconto        24890 non-null  object
#  11  categoria            24890 non-null  object
#  12  tipo_consumo         24890 non-null  object
#  13  tipo_cliente         24890 non-null  object
#  14  custo_produto        24890 non-null  float64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 2.8+ MB

# %%
df['data_pedido']= pd.to_datetime(df['data_pedido'])
df['data_chegada']= pd.to_datetime(df['data_chegada'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24890 entries, 0 to 24889
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pais                 24890 non-null  object
#  1   id_cliente           24890 non-null  int64
#  2   data_pedido          24890 non-null  datetime64[ns]
#  3   data_chegada         24890 non-null  datetime64[ns]
#  4   tipo_compra          24890 non-null  object
#  5   numero_pedido        24890 non-null  int64
#  6   tamanho_pacote       24890 non-null  object
#  7   unidades             24890 non-null  int64
#  8   custo_empacotamento  24890 non-null  float64
#  9   custo_envio          24890 non-null  float64
#  10  tipo_desconto        24890 non-null  object
#  11  categoria            24890 non-null  object
#  12  tipo_consumo         24890 non-null  object
#  13  tipo_cliente         24890 non-null  object
#  14  custo_produto        24890 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(7)
# memory usage: 2.8+ MB

# %%
df_paises_pedidos = df.groupby(['pais'])['unidades'].sum().nlargest(9).copy()
df_paises_pedidos = df_paises_pedidos.reset_index()
df_paises_pedidos.columns = ['País', 'Unidades']
df_paises_pedidos
# Out:
#         País  Unidades
# 0  Argentina      5591
# 1    Equador      5566
# 2   Paraguai      5564
# 3       Peru      5550
# 4  Venezuela      5529
# 5   Colômbia      5504
# 6     Brasil      5473
# 7    Uruguai      5377
# 8      Chile      5304

# %%
df_paises_pedidos['Rank'] = df_paises_pedidos.index +1
df_paises_pedidos.set_index('Rank', inplace = True)
df_paises_pedidos
# Out:
#            País  Unidades
# Rank
# 1     Argentina      5591
# 2       Equador      5566
# 3      Paraguai      5564
# 4          Peru      5550
# 5     Venezuela      5529
# 6      Colômbia      5504
# 7        Brasil      5473
# 8       Uruguai      5377
# 9         Chile      5304

# %% [markdown]
# # Aula 02
# Aprendemos a construir uma visualização capaz de destacar elementos através de algumas funções built-in. E, nesse desafio, podemos aplicar algumas dessas funções.
# O objetivo desse desafio é construir uma visualização que permita identificar quais categorias de produto geraram mais e menos custos para a loja.
#
# Lembrando que, para dar continuidade ao desafio, você precisa ter feito o download do conjunto de dados loja_livro_filmes.csv. O dicionário de dados que descreve esse conjunto está disponível no desafio da aula 1.

# %% [markdown]
# ## Desafio 01
# O objetivo desse desafio é construir uma visualização que permita identificar quais categorias de produto geraram mais e menos custos para a loja.

# %%
df.head()
# Out:
#         pais  id_cliente data_pedido data_chegada tipo_compra  numero_pedido
# 0  Argentina   111962928  2002-02-15   2002-03-10      Normal       98091426  \
# 1  Argentina   145148150  2004-11-05   2004-11-26      Normal       98087803
# 2  Argentina   194622983  2014-09-14   2014-09-28      Normal       98072296
# 3  Argentina   220834258  2011-07-20   2011-07-30   Devolução       98077986
# 4  Argentina   220834258  2013-09-15   2017-02-15      Normal       98074234
#
#    tamanho_pacote  unidades  custo_empacotamento  custo_envio tipo_desconto
# 0  Pacote pequeno         1                  3.0         5.99  Sem desconto  \
# 1  Pacote pequeno         3                  1.0         6.99  Sem desconto
# 2  Pacote pequeno         1                  3.0         6.99  Sem desconto
# 3  Pacote pequeno         2                  1.0         3.86  Cyber Monday
# 4  Pacote pequeno         1                  2.0         4.88  Black Friday
#
#   categoria  tipo_consumo tipo_cliente  custo_produto
# 0   BlueRay  Alto Consumo          B2C           8.99
# 1   BlueRay  Alto Consumo          B2C           7.99
# 2   BlueRay  Alto Consumo          B2C           9.99
# 3   BlueRay  Alto Consumo          B2B           4.86
# 4   BlueRay  Alto Consumo          B2B           6.88

# %%
df_cat = df.groupby(['categoria'])['custo_produto'].sum().copy()
df_cat = df_cat.reset_index()
df_cat.columns = ['Categoria do produto', 'Custo de pedidos']
df_cat
# Out:
#   Categoria do produto  Custo de pedidos
# 0              BlueRay          14191.36
# 1                   CD          10514.28
# 2              Coleção          73128.59
# 3                Livro          78213.80

# %%
#criando a visualizaçao
s_cat = df_cat.style

s_cat.format({'Custo de pedidos':'R$ {:,.2f}'})\
         .highlight_max(color='#F16165')\
         .highlight_min(color='darkgreen')
# Out:
# <style type="text/css">
# #T_38209_row0_col0, #T_38209_row1_col1 {
#   background-color: darkgreen;
# }
# #T_38209_row3_col0, #T_38209_row3_col1 {
#   background-color: #F16165;
# }
# </style>
# <table id="T_38209" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38209_level0_col0" class="col_heading level0 col0" >Categoria do produto</th>
#       <th id="T_38209_level0_col1" class="col_heading level0 col1" >Custo de pedidos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38209_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38209_row0_col0" class="data row0 col0" >BlueRay</td>
#       <td id="T_38209_row0_col1" class="data row0 col1" >R$ 14,191.36</td>
#     </tr>
#     <tr>
#       <th id="T_38209_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38209_row1_col0" class="data row1 col0" >CD</td>
#       <td id="T_38209_row1_col1" class="data row1 col1" >R$ 10,514.28</td>
#     </tr>
#     <tr>
#       <th id="T_38209_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38209_row2_col0" class="data row2 col0" >Coleção</td>
#       <td id="T_38209_row2_col1" class="data row2 col1" >R$ 73,128.59</td>
#     </tr>
#     <tr>
#       <th id="T_38209_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38209_row3_col0" class="data row3 col0" >Livro</td>
#       <td id="T_38209_row3_col1" class="data row3 col1" >R$ 78,213.80</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Aula 03
# Aprendemos a adicionar uma visualização gráfica na nossa tabela através da função bar. Nesse desafio, podemos aplicar essa função para treinarmos a construção da visualização com adição gráfica de uma forma bem similar ao que fizemos na aula.

# %% [markdown]
# ##Desafio 01
# O desafio é construir uma visualização que permita informar a quantidade e distribuição de pedidos por tipo de desconto. Isso irá permitir que os setores da empresa entendam a demanda de produtos em cada ação promocional.

# %%
df.head()
# Out:
#         pais  id_cliente data_pedido data_chegada tipo_compra  numero_pedido
# 0  Argentina   111962928  2002-02-15   2002-03-10      Normal       98091426  \
# 1  Argentina   145148150  2004-11-05   2004-11-26      Normal       98087803
# 2  Argentina   194622983  2014-09-14   2014-09-28      Normal       98072296
# 3  Argentina   220834258  2011-07-20   2011-07-30   Devolução       98077986
# 4  Argentina   220834258  2013-09-15   2017-02-15      Normal       98074234
#
#    tamanho_pacote  unidades  custo_empacotamento  custo_envio tipo_desconto
# 0  Pacote pequeno         1                  3.0         5.99  Sem desconto  \
# 1  Pacote pequeno         3                  1.0         6.99  Sem desconto
# 2  Pacote pequeno         1                  3.0         6.99  Sem desconto
# 3  Pacote pequeno         2                  1.0         3.86  Cyber Monday
# 4  Pacote pequeno         1                  2.0         4.88  Black Friday
#
#   categoria  tipo_consumo tipo_cliente  custo_produto
# 0   BlueRay  Alto Consumo          B2C           8.99
# 1   BlueRay  Alto Consumo          B2C           7.99
# 2   BlueRay  Alto Consumo          B2C           9.99
# 3   BlueRay  Alto Consumo          B2B           4.86
# 4   BlueRay  Alto Consumo          B2B           6.88

# %%
import pandas as pd
descontos = pd.DataFrame(df['tipo_desconto'].value_counts())

#Ajustando a coluna e index
descontos.index.name = 'Tipo de desconto'
descontos.columns = ['Quantidade de pedidos']

#Criando a distribuição da qtd de pedidos por porcentagem
porcentagem = descontos['Quantidade de pedidos'].to_numpy()
porcentagem = 100 * porcentagem/porcentagem.sum()
descontos['Distribuição de Pedidos'] = porcentagem
descontos
# Out:
#                   Quantidade de pedidos  Distribuição de Pedidos
# Tipo de desconto
# Sem desconto                      13347                53.623945
# Cyber Monday                       6922                27.810366
# Black Friday                       1986                 7.979108
# Liquidação                         1487                 5.974287
# Data especial                      1148                 4.612294

# %%
#Criando a visualização
s_descontos = descontos.style
# Propriedades CSS para formatar a visualizaçao
cabecalho = {
    'selector':'th',
    'props': 'font-weight: bold; font-family: Arial; text-align: center; background-color: white; color: black;'
}

celulas = {
    'selector':'td',
    'props': 'background-color: white; color:black;'
}
#Acrescentando o estilo na tabela
s_descontos.set_table_styles([cabecalho, celulas], overwrite = False)
# Out:
# <style type="text/css">
# #T_a26f0 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T_a26f0 td {
#   background-color: white;
#   color: black;
# }
# </style>
# <table id="T_a26f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a26f0_level0_col0" class="col_heading level0 col0" >Quantidade de pedidos</th>
#       <th id="T_a26f0_level0_col1" class="col_heading level0 col1" >Distribuição de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de desconto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a26f0_level0_row0" class="row_heading level0 row0" >Sem desconto</th>
#       <td id="T_a26f0_row0_col0" class="data row0 col0" >13347</td>
#       <td id="T_a26f0_row0_col1" class="data row0 col1" >53.623945</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row1" class="row_heading level0 row1" >Cyber Monday</th>
#       <td id="T_a26f0_row1_col0" class="data row1 col0" >6922</td>
#       <td id="T_a26f0_row1_col1" class="data row1 col1" >27.810366</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row2" class="row_heading level0 row2" >Black Friday</th>
#       <td id="T_a26f0_row2_col0" class="data row2 col0" >1986</td>
#       <td id="T_a26f0_row2_col1" class="data row2 col1" >7.979108</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row3" class="row_heading level0 row3" >Liquidação</th>
#       <td id="T_a26f0_row3_col0" class="data row3 col0" >1487</td>
#       <td id="T_a26f0_row3_col1" class="data row3 col1" >5.974287</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row4" class="row_heading level0 row4" >Data especial</th>
#       <td id="T_a26f0_row4_col0" class="data row4 col0" >1148</td>
#       <td id="T_a26f0_row4_col1" class="data row4 col1" >4.612294</td>
#     </tr>
#   </tbody>
# </table>

# %%
#aplicando a visualização de grafio
# os parâmetros height e width permitem alterar a proporção do tamanho do gráfico em relação a padrão 100

s_descontos.format({'Distribuição de Pedidos': '{:.2f} %'})\
           .bar(subset='Distribuição de Pedidos', vmin = 0, vmax = 100.0, color = '#093364',
                height=50,width=60)
# Out:
# <style type="text/css">
# #T_a26f0 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T_a26f0 td {
#   background-color: white;
#   color: black;
# }
# #T_a26f0_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 32.2%, transparent 32.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_a26f0_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 16.7%, transparent 16.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_a26f0_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 4.8%, transparent 4.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_a26f0_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 3.6%, transparent 3.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_a26f0_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 2.8%, transparent 2.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# </style>
# <table id="T_a26f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a26f0_level0_col0" class="col_heading level0 col0" >Quantidade de pedidos</th>
#       <th id="T_a26f0_level0_col1" class="col_heading level0 col1" >Distribuição de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de desconto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a26f0_level0_row0" class="row_heading level0 row0" >Sem desconto</th>
#       <td id="T_a26f0_row0_col0" class="data row0 col0" >13347</td>
#       <td id="T_a26f0_row0_col1" class="data row0 col1" >53.62 %</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row1" class="row_heading level0 row1" >Cyber Monday</th>
#       <td id="T_a26f0_row1_col0" class="data row1 col0" >6922</td>
#       <td id="T_a26f0_row1_col1" class="data row1 col1" >27.81 %</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row2" class="row_heading level0 row2" >Black Friday</th>
#       <td id="T_a26f0_row2_col0" class="data row2 col0" >1986</td>
#       <td id="T_a26f0_row2_col1" class="data row2 col1" >7.98 %</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row3" class="row_heading level0 row3" >Liquidação</th>
#       <td id="T_a26f0_row3_col0" class="data row3 col0" >1487</td>
#       <td id="T_a26f0_row3_col1" class="data row3 col1" >5.97 %</td>
#     </tr>
#     <tr>
#       <th id="T_a26f0_level0_row4" class="row_heading level0 row4" >Data especial</th>
#       <td id="T_a26f0_row4_col0" class="data row4 col0" >1148</td>
#       <td id="T_a26f0_row4_col1" class="data row4 col1" >4.61 %</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #Aula 03
# Durante a aula, aprendemos a lidar com muitos dados em uma tabela através da fixação de coluna pelo método set_sticky. Vamos lidar com muitos dados nesse desafio para podermos fixar o conteúdo aprendido.

# %% [markdown]
# ## Desafio 01
# Nosso desafio agora é fornecer uma visualização que permita mostrar o tempo médio de entrega de pedidos durante os meses dos anos de 2013 a 2015 por cada país. Isso vai permitir analisar o desempenho da parte de transportes da empresa durante os anos e traçar um planejamento de melhorias.

# %%
#ajustando os dados das colunas para formato de imagem
df['data_chegada'] = pd.to_datetime(df['data_chegada'])
df['data_pedido'] = pd.to_datetime(df['data_pedido'])

#construindo o DF
df_datas = df.copy()
df_datas = df_datas.sort_values('data_pedido')
df_datas = df_datas.reset_index(drop=True)

# Coletando apenas as infos a partir de 2013
df_datas = df_datas[df_datas['data_pedido'] >= '2013-01-01']

#adicionando coluna com os meses formatados
df_datas['meses'] = df_datas['data_pedido'].dt.strftime('%Y - %b')

#adicionar uma coluna com a diferença do tempo de entrega entre pedido e chegada
tempo_demora = (df_datas['data_chegada'] - df_datas['data_pedido']).dt.days
df_datas['tempo_entrega'] = tempo_demora

#criando estrutura em DataFrame
entregas = df_datas.pivot_table(index = 'pais', columns = 'meses', values = 'tempo_entrega', aggfunc ='mean', sort = False)

#criando a visualização
s_entregas = entregas.style.format('{:,.2f}')
s_entregas.set_sticky(axis = 'index')
# Out:
# <style type="text/css">
# #T_31b21 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_31b21 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_31b21" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >meses</th>
#       <th id="T_31b21_level0_col0" class="col_heading level0 col0" >2013 - Jan</th>
#       <th id="T_31b21_level0_col1" class="col_heading level0 col1" >2013 - Feb</th>
#       <th id="T_31b21_level0_col2" class="col_heading level0 col2" >2013 - Mar</th>
#       <th id="T_31b21_level0_col3" class="col_heading level0 col3" >2013 - Apr</th>
#       <th id="T_31b21_level0_col4" class="col_heading level0 col4" >2013 - May</th>
#       <th id="T_31b21_level0_col5" class="col_heading level0 col5" >2013 - Jun</th>
#       <th id="T_31b21_level0_col6" class="col_heading level0 col6" >2013 - Jul</th>
#       <th id="T_31b21_level0_col7" class="col_heading level0 col7" >2013 - Aug</th>
#       <th id="T_31b21_level0_col8" class="col_heading level0 col8" >2013 - Sep</th>
#       <th id="T_31b21_level0_col9" class="col_heading level0 col9" >2013 - Oct</th>
#       <th id="T_31b21_level0_col10" class="col_heading level0 col10" >2013 - Nov</th>
#       <th id="T_31b21_level0_col11" class="col_heading level0 col11" >2013 - Dec</th>
#       <th id="T_31b21_level0_col12" class="col_heading level0 col12" >2014 - Jan</th>
#       <th id="T_31b21_level0_col13" class="col_heading level0 col13" >2014 - Feb</th>
#       <th id="T_31b21_level0_col14" class="col_heading level0 col14" >2014 - Mar</th>
#       <th id="T_31b21_level0_col15" class="col_heading level0 col15" >2014 - Apr</th>
#       <th id="T_31b21_level0_col16" class="col_heading level0 col16" >2014 - May</th>
#       <th id="T_31b21_level0_col17" class="col_heading level0 col17" >2014 - Jun</th>
#       <th id="T_31b21_level0_col18" class="col_heading level0 col18" >2014 - Jul</th>
#       <th id="T_31b21_level0_col19" class="col_heading level0 col19" >2014 - Aug</th>
#       <th id="T_31b21_level0_col20" class="col_heading level0 col20" >2014 - Sep</th>
#       <th id="T_31b21_level0_col21" class="col_heading level0 col21" >2014 - Oct</th>
#       <th id="T_31b21_level0_col22" class="col_heading level0 col22" >2014 - Nov</th>
#       <th id="T_31b21_level0_col23" class="col_heading level0 col23" >2014 - Dec</th>
#       <th id="T_31b21_level0_col24" class="col_heading level0 col24" >2015 - Jan</th>
#       <th id="T_31b21_level0_col25" class="col_heading level0 col25" >2015 - Feb</th>
#       <th id="T_31b21_level0_col26" class="col_heading level0 col26" >2015 - Mar</th>
#       <th id="T_31b21_level0_col27" class="col_heading level0 col27" >2015 - Apr</th>
#       <th id="T_31b21_level0_col28" class="col_heading level0 col28" >2015 - May</th>
#       <th id="T_31b21_level0_col29" class="col_heading level0 col29" >2015 - Jun</th>
#       <th id="T_31b21_level0_col30" class="col_heading level0 col30" >2015 - Jul</th>
#       <th id="T_31b21_level0_col31" class="col_heading level0 col31" >2015 - Aug</th>
#       <th id="T_31b21_level0_col32" class="col_heading level0 col32" >2015 - Sep</th>
#       <th id="T_31b21_level0_col33" class="col_heading level0 col33" >2015 - Oct</th>
#       <th id="T_31b21_level0_col34" class="col_heading level0 col34" >2015 - Nov</th>
#       <th id="T_31b21_level0_col35" class="col_heading level0 col35" >2015 - Dec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pais</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31b21_level0_row0" class="row_heading level0 row0" >Chile</th>
#       <td id="T_31b21_row0_col0" class="data row0 col0" >90.21</td>
#       <td id="T_31b21_row0_col1" class="data row0 col1" >341.24</td>
#       <td id="T_31b21_row0_col2" class="data row0 col2" >470.11</td>
#       <td id="T_31b21_row0_col3" class="data row0 col3" >351.70</td>
#       <td id="T_31b21_row0_col4" class="data row0 col4" >195.55</td>
#       <td id="T_31b21_row0_col5" class="data row0 col5" >99.73</td>
#       <td id="T_31b21_row0_col6" class="data row0 col6" >307.23</td>
#       <td id="T_31b21_row0_col7" class="data row0 col7" >207.92</td>
#       <td id="T_31b21_row0_col8" class="data row0 col8" >321.06</td>
#       <td id="T_31b21_row0_col9" class="data row0 col9" >137.70</td>
#       <td id="T_31b21_row0_col10" class="data row0 col10" >80.67</td>
#       <td id="T_31b21_row0_col11" class="data row0 col11" >285.69</td>
#       <td id="T_31b21_row0_col12" class="data row0 col12" >633.85</td>
#       <td id="T_31b21_row0_col13" class="data row0 col13" >483.75</td>
#       <td id="T_31b21_row0_col14" class="data row0 col14" >658.22</td>
#       <td id="T_31b21_row0_col15" class="data row0 col15" >252.60</td>
#       <td id="T_31b21_row0_col16" class="data row0 col16" >309.82</td>
#       <td id="T_31b21_row0_col17" class="data row0 col17" >469.79</td>
#       <td id="T_31b21_row0_col18" class="data row0 col18" >149.89</td>
#       <td id="T_31b21_row0_col19" class="data row0 col19" >358.42</td>
#       <td id="T_31b21_row0_col20" class="data row0 col20" >403.83</td>
#       <td id="T_31b21_row0_col21" class="data row0 col21" >341.12</td>
#       <td id="T_31b21_row0_col22" class="data row0 col22" >327.12</td>
#       <td id="T_31b21_row0_col23" class="data row0 col23" >329.43</td>
#       <td id="T_31b21_row0_col24" class="data row0 col24" >530.29</td>
#       <td id="T_31b21_row0_col25" class="data row0 col25" >549.07</td>
#       <td id="T_31b21_row0_col26" class="data row0 col26" >606.28</td>
#       <td id="T_31b21_row0_col27" class="data row0 col27" >424.06</td>
#       <td id="T_31b21_row0_col28" class="data row0 col28" >423.43</td>
#       <td id="T_31b21_row0_col29" class="data row0 col29" >353.83</td>
#       <td id="T_31b21_row0_col30" class="data row0 col30" >432.64</td>
#       <td id="T_31b21_row0_col31" class="data row0 col31" >447.47</td>
#       <td id="T_31b21_row0_col32" class="data row0 col32" >314.11</td>
#       <td id="T_31b21_row0_col33" class="data row0 col33" >502.29</td>
#       <td id="T_31b21_row0_col34" class="data row0 col34" >406.92</td>
#       <td id="T_31b21_row0_col35" class="data row0 col35" >254.91</td>
#     </tr>
#     <tr>
#       <th id="T_31b21_level0_row1" class="row_heading level0 row1" >Uruguai</th>
#       <td id="T_31b21_row1_col0" class="data row1 col0" >180.88</td>
#       <td id="T_31b21_row1_col1" class="data row1 col1" >201.27</td>
#       <td id="T_31b21_row1_col2" class="data row1 co

# %% [markdown]
# #Aula 04

# %% [markdown]
# ##Desafio 01
# A empresa que estamos trabalhando distribui produtos por toda América do Sul para várias categorias de clientes. Nosso desafio envolve uma visualização que permita separar os gastos de envio de cada produto (custo total) por tipo de cliente, de modo que seja possível entender o tipo de produto que mais gerou custos de envio em cada tipo de cliente. Além disso, é interessante também mostrar a distribuição desses custos por país enviado, permitindo entender também os gastos por país.
#
# Lembrando que, para dar continuidade ao desafio, você precisa ter feito o download do conjunto de dados loja_livro_filmes.csv. O dicionário de dados que descreve esse conjunto está disponível no desafio da aula 1.

# %%
df
# Out:
#             pais  id_cliente data_pedido data_chegada tipo_compra
# 0      Argentina   111962928  2002-02-15   2002-03-10      Normal  \
# 1      Argentina   145148150  2004-11-05   2004-11-26      Normal
# 2      Argentina   194622983  2014-09-14   2014-09-28      Normal
# 3      Argentina   220834258  2011-07-20   2011-07-30   Devolução
# 4      Argentina   220834258  2013-09-15   2017-02-15      Normal
# ...          ...         ...         ...          ...         ...
# 24885  Venezuela   890670789  2006-05-05   2006-05-18   Devolução
# 24886  Venezuela   892274535  2002-02-20   2002-03-08      Normal
# 24887  Venezuela   892274535  2015-01-26   2015-02-17      Normal
# 24888  Venezuela   898039697  2002-08-22   2002-09-06      Normal
# 24889  Venezuela   898039697  2009-05-27   2009-06-17      Normal
#
#        numero_pedido  tamanho_pacote  unidades  custo_empacotamento
# 0           98091426  Pacote pequeno         1                  3.0  \
# 1           98087803  Pacote pequeno         3                  1.0
# 2           98072296  Pacote pequeno         1                  3.0
# 3           98077986  Pacote pequeno         2                  1.0
# 4           98074234  Pacote pequeno         1                  2.0
# ...              ...             ...       ...                  ...
# 24885       98085835  Pacote pequeno         2                  1.0
# 24886       98091414  Pacote pequeno         1                  2.0
# 24887       98071516  Pacote pequeno         3                  3.0
# 24888       98090720  Pacote pequeno         2                  2.0
# 24889       98081676  Pacote pequeno         1                  1.0
#
#        custo_envio tipo_desconto categoria  tipo_consumo tipo_cliente
# 0             5.99  Sem desconto   BlueRay  Alto Consumo          B2C  \
# 1             6.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 2             6.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 3             3.86  Cyber Monday   BlueRay  Alto Consumo          B2B
# 4             4.88  Black Friday   BlueRay  Alto Consumo          B2B
# ...            ...           ...       ...           ...          ...
# 24885         6.99  Sem desconto     Livro  Alto Consumo          B2C
# 24886         6.25  Cyber Monday     Livro  Alto Consumo          B2B
# 24887         4.65  Sem desconto     Livro  Alto Consumo          B2B
# 24888         4.58  Sem desconto     Livro  Alto Consumo          B2B
# 24889         6.65  Sem desconto     Livro  Alto Consumo          B2B
#
#        custo_produto
# 0               8.99
# 1               7.99
# 2               9.99
# 3               4.86
# 4               6.88
# ...              ...
# 24885           7.99
# 24886           8.25
# 24887           7.65
# 24888           6.58
# 24889           7.65
#
# [24890 rows x 15 columns]

# %%
custo = df.pivot_table(index = 'tipo_cliente', columns = 'categoria', values = 'custo_produto', aggfunc ='sum')
custo
# Out:
# categoria     BlueRay       CD   Coleção     Livro
# tipo_cliente
# B2B           4955.45  3603.63  25156.22  26775.22
# B2C           9235.91  6910.65  47972.37  51438.58

# %%
estilo_custo = custo.style.format('{:,.2f}')

cabecalho = {
    'selector': 'th',
    'props': 'font-weight: bold; font-family: Arial; text-align: center; background-color: grey'
}
celulas = {
    'selector': 'td',
    'props': 'background-color: grey;'
}
estilo_custo.set_table_styles([cabecalho, celulas], overwrite = False)
# Out:
# <style type="text/css">
# #T_f33a1 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   background-color: grey;
# }
# #T_f33a1 td {
#   background-color: grey;
# }
# </style>
# <table id="T_f33a1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >categoria</th>
#       <th id="T_f33a1_level0_col0" class="col_heading level0 col0" >BlueRay</th>
#       <th id="T_f33a1_level0_col1" class="col_heading level0 col1" >CD</th>
#       <th id="T_f33a1_level0_col2" class="col_heading level0 col2" >Coleção</th>
#       <th id="T_f33a1_level0_col3" class="col_heading level0 col3" >Livro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f33a1_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_f33a1_row0_col0" class="data row0 col0" >4,955.45</td>
#       <td id="T_f33a1_row0_col1" class="data row0 col1" >3,603.63</td>
#       <td id="T_f33a1_row0_col2" class="data row0 col2" >25,156.22</td>
#       <td id="T_f33a1_row0_col3" class="data row0 col3" >26,775.22</td>
#     </tr>
#     <tr>
#       <th id="T_f33a1_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_f33a1_row1_col0" class="data row1 col0" >9,235.91</td>
#       <td id="T_f33a1_row1_col1" class="data row1 col1" >6,910.65</td>
#       <td id="T_f33a1_row1_col2" class="data row1 col2" >47,972.37</td>
#       <td id="T_f33a1_row1_col3" class="data row1 col3" >51,438.58</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Considerando os paises
# Criar um DataFrame alternativo para ter um nome de coluna coerente com a visualização
df_alteracao = df.rename(columns={'pais': 'Custo por país ($)'})

# Agrupar os dados de tipo de cliente, com a categoria de produtos e os países que esses clientes importam o produto
df_clientes = df_alteracao.pivot_table(index=['tipo_cliente', 'categoria'], columns = 'Custo por país ($)', values = 'custo_produto', aggfunc = 'sum')

# Renomear o cabeçalho para nomes mais coerentes
df_clientes.rename_axis(index={'tipo_cliente': 'Tipo cliente', 'categoria': 'Categoria produto'}, inplace = True)

# Adicionar uma coluna que mostra a soma dos custos por tipo de cliente e categoria de produto
df_clientes['Total ($)'] = df_clientes.sum(axis=1)

## Criar a visualização
s_clientes = df_clientes.style.format('{:,.2f}')

# Criar os estilos base para a tabela, a partir da padronização das fontes, plano de fundo para branco e o alinhamento do cabeçalho para o topo
tabela = {
    'selector': 'td, th',
    'props': 'font-weight: normal; font-family: Arial; text-align: right; background-color: grey;'
}
# Alinhar verticalmente o cabeçalho para o topo permite a pessoa observadora identificar onde começa a hierarquização dos grupos B2B e B2C
cabecalho = {
    'selector': 'th',
    'props': 'vertical-align: top'
}
s_clientes.set_table_styles([tabela, cabecalho])

# Adicionar linha de separação do cabeçalho superior
# Destacar as categorias que mais geraram custo com a aplicação de negrito nas fontes
s_clientes.set_table_styles({
    ('B2B', 'BlueRay'): [{'selector': 'th', 'props': 'border-top: 1px solid #181818'},
              {'selector': 'td', 'props': 'border-top: 1px solid #181818'}],
    ('B2B', 'Livro'): [{'selector': 'th', 'props': 'font-weight: bold'}],
    ('B2C', 'Livro'): [{'selector': 'th', 'props': 'font-weight: bold'}],
}, overwrite=False, axis=1)

# Destacar os elementos em cada tipo de cliente que mais geraram custos com uma seleção
s_clientes.set_table_styles({
    'Total ($)': [{
        'selector': '.true',
        'props': 'font-weight: bold'
    }]
},overwrite=False,axis=0)

cores_coluna = pd.DataFrame(['false','false','false','true','false','false','false','true'],index= df_clientes['Total ($)'].index,
                            columns = ['Total ($)'])
# Visualização final
s_clientes.set_td_classes(cores_coluna)
# Out:
# <style type="text/css">
# #T_ecd8b td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: right;
#   background-color: grey;
# }
# #T_ecd8b  th {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: right;
#   background-color: grey;
# }
# #T_ecd8b th {
#   vertical-align: top;
# }
# #T_ecd8b th.row0 {
#   border-top: 1px solid #181818;
# }
# #T_ecd8b td.row0 {
#   border-top: 1px solid #181818;
# }
# #T_ecd8b th.row3 {
#   font-weight: bold;
# }
# #T_ecd8b th.row7 {
#   font-weight: bold;
# }
# #T_ecd8b .true.col9 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ecd8b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Custo por país ($)</th>
#       <th id="T_ecd8b_level0_col0" class="col_heading level0 col0" >Argentina</th>
#       <th id="T_ecd8b_level0_col1" class="col_heading level0 col1" >Brasil</th>
#       <th id="T_ecd8b_level0_col2" class="col_heading level0 col2" >Chile</th>
#       <th id="T_ecd8b_level0_col3" class="col_heading level0 col3" >Colômbia</th>
#       <th id="T_ecd8b_level0_col4" class="col_heading level0 col4" >Equador</th>
#       <th id="T_ecd8b_level0_col5" class="col_heading level0 col5" >Paraguai</th>
#       <th id="T_ecd8b_level0_col6" class="col_heading level0 col6" >Peru</th>
#       <th id="T_ecd8b_level0_col7" class="col_heading level0 col7" >Uruguai</th>
#       <th id="T_ecd8b_level0_col8" class="col_heading level0 col8" >Venezuela</th>
#       <th id="T_ecd8b_level0_col9" class="col_heading level0 col9" >Total ($)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo cliente</th>
#       <th class="index_name level1" >Categoria produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecd8b_level0_row0" class="row_heading level0 row0" rowspan="4">B2B</th>
#       <th id="T_ecd8b_level1_row0" class="row_heading level1 row0" >BlueRay</th>
#       <td id="T_ecd8b_row0_col0" class="data row0 col0" >488.23</td>
#       <td id="T_ecd8b_row0_col1" class="data row0 col1" >552.31</td>
#       <td id="T_ecd8b_row0_col2" class="data row0 col2" >521.31</td>
#       <td id="T_ecd8b_row0_col3" class="data row0 col3" >538.39</td>
#       <td id="T_ecd8b_row0_col4" class="data row0 col4" >473.88</td>
#       <td id="T_ecd8b_row0_col5" class="data row0 col5" >596.74</td>
#       <td id="T_ecd8b_row0_col6" class="data row0 col6" >727.11</td>
#       <td id="T_ecd8b_row0_col7" class="data row0 col7" >580.81</td>
#       <td id="T_ecd8b_row0_col8" class="data row0 col8" >476.67</td>
#       <td id="T_ecd8b_row0_col9" class="data row0 col9 false" >4,955.45</td>
#     </tr>
#     <tr>
#       <th id="T_ecd8b_level1_row1" class="row_heading level1 row1" >CD</th>
#       <td id="T_ecd8b_row1_col0" class="data row1 col0" >344.74</td>
#       <td id="T_ecd8b_row1_col1" class="data row1 col1" >449.66</td>
#       <td id="T_ecd8b_row1_col2" class="data row1 col2" >350.58</td>
#       <td id="T_ecd8b_row1_col3" class="data row1 col3" >422.22</td>
#       <td id="T_ecd8b_row1_col4" class="data row1 col4" >396.15</td>
#       <td id="T_ecd8b_row1_col5" class="data row1 col5" >341.49</td>
#       <td id="T_ecd8b_row1_col6" class="data row1 col6" >388.17</td>
#       <td id="T_ecd8b_row1_col7" class="data row1 col7" >495.02</td>
#       <td id="T_ecd8b_row1_col8" class="data row1 col8" >415.60</td>
#       <td id="T_ecd8b_row1_col9" class="data row1 col9 false" >3,603.63</td>
#     </tr>
#     <tr>
#       <th id="T_ecd8b_level1_row2" class="row_heading level1 row2" >Coleção</th>
#       <td id="T_ecd8b_row2_col0" class="data row2 col0" >2,824.31</td>
#       <td id="T_ecd8b_row2_col1" class="data row2 col1" >2,899.26</td>
#       <td id="T_ecd8b_row2_col2" class="data row2 col2" >2,939.29</td>
#       <td id="T_ecd8b_row2_col3" class="data row2 col3" >2,823.34</td>
#       <td id="T_ecd8b_row2_col4" class="data row2 col4" >2,747.09</td>
#       <td id="T_ecd8b_row2_col5" class="data row2 col5" >2,492.20</td>
#       <td id="T_ecd8b_row2_col6" class="data row2 col6" >2,912.78</td>
#       <td id="T_ecd8b_row2_col7" class="data row2 col7" >2,548.28</td>
#       <td id="T_ecd8b_row2_col8" class="data row2 col8" >2,969.67</td>
#       <td id="T_ecd8b_row2_col9" class="data row2 col9 false" >25,156.22</td>
#     </tr>
#     <tr>
#       <th id="T_ecd8b_level1_row3" class="row_heading level1 row3" >Livro</th>
#       <td id="T_ecd8b_row3_col0" class="data row3 col0" >3,150.77</td>
#       <td id="T_ecd8b_row3_col1" class="data row3 col1" >2,751.26</td>
#       <td id="T_ecd8b_row3_col2" class="data row3 col2" >2,809.13</td>
#       <td id="T_ecd8b_row3_col3" class="data row3 col3" >2,987.06</td>
#       <td id="T_ecd8b_row3_col4" class="data row3 col4" >3,229.24</td>
#       <td id="T_ecd8b_row3_col5" class="data row3 col5" >3,161.33</td>
#       <td id="T_ecd8b_row3_col6" class="data row3 col6" >3,092.14</td>
#       <td id="T_ecd8b_row3_col7" class="data row3 col7" >2,872.69</td>
#       <td id="T_ecd8b_row3_col8" class="data row3 col8" >2,721.60</td>
#       <td id="T_ecd8b_row3_col9" class="data row3 col9 true" >26,775.22</td>
#     </tr>
#     <tr>
#       <th id="T_ecd8b_level0_row4" class="row_heading level0 row4" rowspan="4">B2C</th>
#       <th id="T_ecd8b_level1_row4" class="row_heading level1 row4" >BlueRay</th>
#       <td id="T_ecd8b_row4_col0" class="data row4 col0" >1,027.85</td>
#       <td id="T_ecd8b_row4_col1" class="data row4 col1" >1,007.18</td>
#       <td id="T_ecd8b_row4_col2" class="data row4 col2" >992.12</td>
#       <td id="T_ecd8b_row4_col3" class="data row4 col3" >1,062.35</td>
#       <td id="T_ecd8b_row4_col4" class="data row4 col4" >1,004.99</td>
#       <td id="T_ecd8b_row4_col5" class="data row4 col5" >1,095.01</td>
#       <td id="T_ecd8b_row4_col6" class="data row4 col6" >1,079.54</td>
#       <td id="T_ecd8b_row4_col7" class="data row4 col7" >873.96</td>
#       <td id="T_ecd8b_row4_col8" class="data row4 col8" >1,092.91</td>
#       <td id="T_ecd8b_row4_col9" class="data row4 col9 false" >9,235.91</td>
#     </tr>
#     <tr>
#       <th id="T_ecd8b_level1_row5" class="row_heading level1 row5" >CD</th>
#       <td id="T_ecd8b_row5_col0" class="data row5 col0" >785.63</td>
#       <td id="T_ecd8b_row5_col1" class="data row5 col1" >860.71</td>
#       <td id="T_ecd8b_row5_col2" class="data row5 col2" >620.83</td>
#       <td id="T_ecd8b_row5_col3" class="data row5 col3" >668.12</td>
#       <td id="T_ecd8b_row5_col4" class="data row5 col4" >666.49</td>
#       <td id="T_ecd8b_row5_col5" class="data row5 col5" >867.01</td>
#       <td id="T_ecd8b_row5_col6" class="data row5 col6" >788.82</td>
#       <td id="T_ecd8b_row5_col7" class="data row5 col7" >795.89</td>
#       <td id="T_ecd8b_row5_col8" class="data row5 col8" >857.15</td>
#       <td id="T_ecd8b_row5_col9" class="data row5 col9 false" >6,910.65</td>
#     </tr>
#     <tr>
#       <th id="T_ecd8b_level1_row6" class="row_heading level1 row6" >Coleção</th>
#       <td id="T_ecd8b_row6_col0" class="data row6 col0" >5,587.93</td>
#       <td id="T_ecd8b_row6_col1" class="data row6 col1" >5,053.64</td>
#       <td id="T_ecd8b_row6_col2" class="data row6 col2" >5,162.34</td>
#       <td id="T_ecd8b_row6_col3" class="data row6 col3" >5,253.09</td>
#       <td id="T_ecd8b_row6_col4" class="data row6 col4" >5,583.83</td>
#       <td id="T_ecd8b_row6_col5" class="data row6 col5" >5,759.34</td>
#       <td id="T_ecd8b_row6_col6" class="data row6 col6" >5,159.96</td>
#       <td id="T_ecd8b_row6_col7" class="data row6 col7" >4,961.45</td>
#       <td id="T_ecd8b_row6_col8" class="data row6 col8" >5,450.79</td>
#       <td id="T_ecd8b_row6_col9" class="data row6 col9 false" >47,972.37</td>
#     </tr>
#     <tr>
#       <th id="T_ecd8b_level1_row7" class="row_heading level1 row7" >Livro</th>
#       <td id=
